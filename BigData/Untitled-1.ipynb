# %% [markdown]
# ### lab 1
#
# ### 1번

# %%
# 1-1
names = "네일"
games = 26
era = 2.53
win = 12
lose = 5
print(names, games, era, win, lose)
# Out:
# 네일 26 2.53 12 5

# %%
# 1-2
print(era < 3.50)
# Out:
# True

# %%
# 1-3
win_rate = win / (win + lose)
print(win_rate)
# Out:
# 0.7058823529411765

# %%
# 1-4
win_rate_avg = round(win / games, 2)
print(win_rate_avg)
# Out:
# 0.46

# %%
# 1-5
print(f"{names} 선수는 {games}경기에 출전하여 {win}승 {lose}패, 방어율 {era}을 기록했습니다.")
# Out:
# 네일 선수는 26경기에 출전하여 12승 5패, 방어율 2.53을 기록했습니다.

# %%
# 1-6
era_str = str(era)
print(type(era_str))
# Out:
# <class 'str'>

# %% [markdown]
# ### 2번

# %%
# 2-1
lyrics = "You, you are my universe and I just want to puy you first"
print(lyrics)
# Out:
# You, you are my universe and I just want to puy you first

# %%
# 2-2
print(len(lyrics))
print(len(lyrics.split()))
# Out:
# 57
# 13

# %%
# 2-3
print(lyrics[16:24])
# Out:
# universe

# %%
# 2-4
lyrics_lower = lyrics.lower()
print(lyrics_lower.count("you"))
# Out:
# 3

# %%
# 2-5
print(lyrics_lower.replace("you", "we"))
# Out:
# we, we are my universe and i just want to puy we first

# %%
# 2-6
words_list = lyrics.split(' ')
print(words_list[1])
print(words_list[12])
# Out:
# you
# first

# %%
# 2-7
words_list = lyrics.split(' ')
print("-".join(words_list[:3]))
# Out:
# You,-you-are
